# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#read the data set
df = pd.read_csv('height_weight_data.csv')
df.head()
# Out:
#    Height (cm)  Weight (kg)
# 0          188         92.1
# 1          178         71.9
# 2          164         65.0
# 3          157         47.2
# 4          170         63.4

# %%
plt.scatter(df['Weight (kg)'], df['Height (cm)'])
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('Weight vs Height')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Height (cm)', 'Weight (kg)'], dtype='object')

# %%
#create a model to get the line 0f best fit

#steps to perform

## Divide the feature based on Data set
# train test split of the data set
#standerdise the data _______> wheree evere there is optimization work standerization rquired

# %%
#divide into dependent and independent
X = df[['Weight (kg)']] # independent
y = df[['Height (cm)']]

# %%
# !pip install scikit-learn

# %%
### Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 45)

# %%
X.shape
# Out:
# (50, 1)

# %%
X_test.shape
# Out:
# (10, 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
plt.scatter(X_train,y_train)

# %%
#tarin simple linear regression  model
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
print ("the slope is ", regression.coef_) # slope
print("Intercept", regression.intercept_)
# Out:
# the slope is  [[9.5888232]]
# Intercept [167.675]

# %%
plt.scatter(X_train , y_train)

# %%
plt.scatter(X_train , y_train)
plt.plot(X_train ,regression.predict(X_train), c = 'g', marker = '*')
